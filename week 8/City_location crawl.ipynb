# %%
import time
from selenium import webdriver
import pandas as pd 
import numpy as np

# %%
df = pd.DataFrame(index=range(len(cityname)))

driver = webdriver.Chrome(executable_path='C:\Program Files (x86)\Google\Chrome\Application\chromedriver.exe')
time0 = time.time()
for num, city in enumerate(cityname):
    driver.get('https://www.google.co.uk/webhp?h1=en&sa=x&ved=0ahUKEwimtcx24cTfAhUJE7wKHVkwB5AQPAgH')
    
    time.sleep(0.3)
    search_box = driver.find_element_by_name('q')
    search_box.send_keys('{} Australia Latitude and longitude'.format(city))
    search_box.submit()
    
    result = driver.find_element_by_xpath('//*[@id="rso"]/div[1]/block-component/div/div[1]/div[1]/div/div/div[1]/div/div/div[2]/div/div/div/div[1]').text
                                           
    
    resultsplit = result.split(" ")
    df.loc[num,'city'] = city
    df.loc[num,'Latitude'] = resultsplit[0]
    df.loc[num,'Longitude'] = resultsplit[2]
    df.loc[num,'Latitudedir'] = resultsplit[1]
    df.loc[num,'Longitudedir'] = resultsplit[3]
    print('{} webcrawler successfuld for city {}'.format(num,city))
    
time.sleep(1)
driver.quit()
print(time.time()-time0)
# Out:
# C:\Users\OEM\AppData\Local\Temp/ipykernel_15656/592595776.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path='C:\Program Files (x86)\Google\Chrome\Application\chromedriver.exe')
# C:\Users\OEM\AppData\Local\Temp/ipykernel_15656/592595776.py:9: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   search_box = driver.find_element_by_name('q')
# C:\Users\OEM\AppData\Local\Temp/ipykernel_15656/592595776.py:13: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   result = driver.find_element_by_xpath('//*[@id="rso"]/div[1]/block-component/div/div[1]/div[1]/div/div/div[1]/div/div/div[2]/div/div/div/div[1]').text
# 0 webcrawler successfuld for city Exmouth
# 1 webcrawler successfuld for city Dampier
# 2 webcrawler successfuld for city Port Hedland
# 3 webcrawler successfuld for city Broome
# 4 webcrawler successfuld for city Derby
# 5 webcrawler successfuld for city Wyndham
# 6 webcrawler successfuld for city Timber Creek
# 7 webcrawler successfuld for city Katherine
# 8 webcrawler successfuld for city Darwin
# 9 webcrawler successfuld for city Oenoelli
# 10 webcrawler successfuld for city Nhulunbuy
# 11 webcrawler successfuld for city Borroloola
# 12 webcrawler successfuld for city Burketown
# 13 webcrawler successfuld for city Weipa
# 14 webcrawler successfuld for city Cooktown
# 15 webcrawler successfuld for city Cairns
# 16 webcrawler successfuld for city Christmas Island
# 17 webcrawler successfuld for city Cocos Island
# 18 webcrawler successfuld for city Karratha
# 19 webcrawler successfuld for city Townsville
# 20 webcrawler successfuld for city Carnarvon
# 21 webcrawler successfuld for city Gascoyne Junction
# 22 webcrawler successfuld for city Newman
# 23 webcrawler successfuld for city Telfer
# 24 webcrawler successfuld for city Yulara
# 25 webcrawler successfuld for city Kulgera
# 26 webcrawler successfuld for city Alice Springs
# 27 webcrawler successfuld for city Tennant Creek
# 28 webcrawler successfuld for city Elliot
# 29 webcrawler successfuld for city Mount Isa
# 30 webcrawler successfuld for city Birdsville
# 31 webcrawler successfuld for city Longreach
# 32 webcrawler successfuld for city Charieville
# 105 webcrawler successfuld for city Rossarden
# 106 webcrawler successfuld for city Smithton
# 107 webcrawler successfuld for city St Marys
# 108 webcrawler successfuld for city Zeehan
# 109 webcrawler successfuld for city Ararat
# 110 webcrawler successfuld for city Bright
# 111 webcrawler successfuld for city Hamilton
# 112 webcrawler successfuld for city Wangaratta
# 237.39908981323242

# %%
cityname = pd.read_csv('Climate-zone-map-aust.csv',encoding='cp1252')
cityname.head()
# Out:
#            City                            Climate
# 0       Exmouth  high humidity summer, warm winter
# 1       Dampier  high humidity summer, warm winter
# 2  Port Hedland  high humidity summer, warm winter
# 3        Broome  high humidity summer, warm winter
# 4         Derby  high humidity summer, warm winter

# %%
cityname = cityname.iloc[:,0].tolist()

# %%
cityname
# Out:
# ['Exmouth',
#  'Dampier',
#  'Port Hedland',
#  'Broome',
#  'Derby',
#  'Wyndham',
#  'Timber Creek',
#  'Katherine',
#  'Darwin',
#  'Oenoelli',
#  'Nhulunbuy',
#  'Borroloola',
#  'Burketown',
#  'Weipa',
#  'Cooktown',
#  'Cairns',
#  'Christmas Island',
#  'Cocos Island',
#  'Karratha',
#  'Townsville',
#  'Carnarvon',
#  'Gascoyne Junction',
#  'Newman',
#  'Telfer',
#  'Yulara',
#  'Kulgera',
#  'Alice Springs',
#  'Tennant Creek',
#  'Elliot',
#  'Mount Isa',
#  'Birdsville',
#  'Longreach',
#  'Charieville',
#  'Thargomindah',
#  'Taroom',
#  'Goondiwindi',
#  'Mackay',
#  'Rockhampton',
#  'Maryborough',
#  'Brisbane',
#  'Coffs Harbour',
#  'Yalgoo',
#  'Wiluna',
#  'Warburton',
#  'Merredin',
#  'Newdegate',
#  'Kalgoorlie-Boulder',
#  'Norseman',
#  'Amata',
#  'Dodnadatta',
#  'Coober Pedy',
#  'Innamincka',
#  'Tibooburra',
#  'Broken Hill',
#  'Mildura',
#  'Bourke',
#  'Ivanhoe',
#  'Griffith',
#  'Albury Wodonga',
#  'Dubbo',
#  'Tamworth',
#  'Geraldton',
#  'Perth',
#  'Bunbury',
#  'Margaret River',
#  'Esperance',
#  'Eucia',
#  'Nullarbor',
#  'Ceduna',
#  'Port Lincoin',
#  'Whyalla',
#  'Leigh Creek',
#  'Adelalde',
#  'Renmark',
#  'Port Macquarie',
#  'Newcastle',
#  'Sydney',
#  'Wollongong',
#  'Albany',
#  'Burra',
#  'Kingscote',
#  'Kingston SE',
#  'Mount Gambier',
#  'Lakes Entrance',
#  'Melbourne',
#  'Shepparton',
#  'Bathurst',
#  'Canberra',
#  'Ballarat',
#  'Armidale',
#  'Ballarat',
#  'Bellingen Shire – Dorrigo Plateau',
#  'Goulburn',
#  'Orange',
#  'Bicheno',
#  'Deloraine',
#  'Devonport',
#  'Flinders Island',
#  'Hobart',
#  'Huonville',
#  'King Island',
#  'Launceston',
#  'New Norfolk',
#  'Oatlands',
#  'Orford',
#  'Rossarden',
#  'Smithton',
#  'St Marys',
#  'Zeehan',
#  'Ararat',
#  'Bright',
#  'Hamilton',
#  'Wangaratta']

# %%
city_ll = df.to_csv('City_ll.csv')
